# %%
import foodbornenyc.models.models as models

# %%
db = models.getDBSession()

# %%
from foodbornenyc.models.documents import YelpReview, Document
from foodbornenyc.models.businesses import Business

# %%
yr = db.query(YelpReview).first()
# Out:
# ---------------------------------------------------------------------------
# NoReferencedTableError                    Traceback (most recent call last)
# <ipython-input-6-683d8dff1aa9> in <module>()
# ----> 1 yr = db.query(YelpReview).first()
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in query(self, *entities, **kwargs)
#    1258         :class:`.Session`."""
#    1259
# -> 1260         return self._query_cls(entities, self, **kwargs)
#    1261
#    1262     @property
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/query.pyc in __init__(self, entities, session)
#     108         self.session = session
#     109         self._polymorphic_adapters = {}
# --> 110         self._set_entities(entities)
#     111
#     112     def _set_entities(self, entities, entity_wrapper=None):
#
# ...

# %%
print yr
# Out:
# <YelpReview: u'Food was mediocre at best.'>

# %%
print yr.document
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9eeeb135a4e1> in <module>()
# ----> 1 print yr.document
#
# /Users/thomaseffland/Development/FoodborneNYC/foodbornenyc/models/documents.py in __repr__(self)
#     135
#     136     def __repr__(self):
# --> 137         return "<Document: %r>" % source
#     138
#     139     def set(self, var_name, var_val):
#
# NameError: global name 'source' is not defined

# %%
print yr.document.member
# Out:
# <YelpReview: u'Food was mediocre at best.'>

# %%
yr = YelpReview(rating=1.0, text="blah", user_name="ufggit", yelp_id='12345')

# %%
doc = Document()
yr.document = doc

# %%
db.add(yr)
db.commit()
# Out:
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/sql/sqltypes.py:185: SAWarning: Unicode type received non-unicode bind param value 'blah'. (this warning may be suppressed after 10 occurrences)
#   (util.ellipses_string(value),))
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-9-fd6e4da10805> in <module>()
#       1 db.add(yr)
# ----> 2 db.commit()
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in commit(self)
#     799                 raise sa_exc.InvalidRequestError("No transaction is begun.")
#     800
# --> 801         self.transaction.commit()
#     802
#     803     def prepare(self):
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in commit(self)
#     390         self._assert_active(prepared_ok=True)
# ...

# %%
db.query(Document).first()
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-10-00e665358853> in <module>()
# ----> 1 db.query(Document).first()
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/query.pyc in first(self)
#    2467             ret = list(self)[0:1]
#    2468         else:
# -> 2469             ret = list(self[0:1])
#    2470         if len(ret) > 0:
#    2471             return ret[0]
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/query.pyc in __getitem__(self, item)
#    2290                 return list(res)[None:None:item.step]
#    2291             else:
# -> 2292                 return list(res)
#    2293         else:
#    2294             if item == -1:
#
# /Users/thomaseffland/.virtualenvs/health/lib/python2.7/site-packages/sqlalchemy/orm/query.pyc in __iter__(self)
# ...
